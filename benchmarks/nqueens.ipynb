# %%
import pandas as pd
import matplotlib.pyplot as plt
#https://timodenk.com/blog/exporting-matplotlib-plots-to-latex/
#http://jonathansoma.com/lede/data-studio/matplotlib/adding-grid-lines-to-a-matplotlib-chart/

# %%
z3 = [7.882,
13.490,
6.083,
9.311,
16.136,
12.199,
15.235,
9.695,
11.060,
20.914,
9.664,
12.658,
28.518,
13.733,
11.137,
23.671,
8.245,
11.400,
9.341,
23.753,
14.143]
clpfd=[
    0.110,
11.215,
0.157,
0.159,
0.247,
1.317,
0.286,
0.226,
319.812,
0.225,
237.690,
0.431,
0.151,
0.225,
0.212,
0,
0.318,
0.871,
0.196,
25.625,
164.719
]
#df_clpfd_nqueens = pd.DataFrame(clpfd, columns=['clpfd'])
#df_z3 = pd.DataFrame(z3, columns=['z3'])
index = [100,
101,
102,
103,
104,
105,
106,
107,
108,
109,
110,
111,
112,
113,
114,
115,
116,
117,
118,
119,
120]
df = pd.DataFrame(list(zip(index,clpfd,z3)), 
               columns =['index', 'clpfd', 'z3']) 
#df = df.set_index('index')
df['index']
# Out:
# 0     100
# 1     101
# 2     102
# 3     103
# 4     104
# 5     105
# 6     106
# 7     107
# 8     108
# 9     109
# 10    110
# 11    111
# 12    112
# 13    113
# 14    114
# 15    115
# 16    116
# 17    117
# 18    118
# 19    119
# 20    120
# Name: index, dtype: int64

# %%
fig,ax = plt.subplots()
df.plot.bar(x='index', logy=True, figsize=(15,10), ax=ax)
ax.grid(which='major', linestyle='-.', linewidth=1, color='black')
ax.grid(which='minor', linestyle=':', linewidth='0.3', color='grey')
ax.set_axisbelow(True)
ax.set_ylabel('Time in seconds - logarithmic scale')
ax.set_xlabel('N')
ax.xaxis.grid(False)
ax.legend(loc='best')
fig.savefig('abc')

# %%
#df_merged['z3_labeling'].plot(x='bibd', kind='bar')

# %%
fig,ax = plt.subplots()
df_dropped.plot.bar(x='bibd', logy=True, figsize=(15,10), ax=ax)
ax.grid(which='major', linestyle='-.', linewidth=1, color='grey')
ax.grid(which='minor', linestyle=':', linewidth='0.3', color='black')
ax.set_axisbelow(True)
ax.set_ylabel('Time in seconds - logarithmic scale')
ax.xaxis.grid(False)
ax.legend(loc='best')
